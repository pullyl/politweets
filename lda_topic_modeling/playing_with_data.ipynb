# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('combinedtweets.csv', encoding='utf-8')
df.head()
# Out:
# /Users/allison18paige/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0,1,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Unnamed: 0                  id           created_at coordinates retweets  \
# 0          0  774819800036040704  2016-09-11 04:00:10         NaN        3
# 1          1  771312761275953152  2016-09-01 11:44:27         NaN        5
# 2          2  769220580755304448  2016-08-26 17:10:52         NaN        1
# 3          3  768469764385550336  2016-08-24 15:27:23         NaN        1
# 4          4  764242050640412672  2016-08-12 23:27:58         NaN        4
#
#   favorite_count              source  \
# 0             12              Buffer
# 1              6     Mobile Web (M5)
# 2              2  Twitter Web Client
# 3              3  Twitter Web Client
# 4              8  Twitter Web Client
#
#                                                 text        twitter last_name  \
# 0  Never Forget. https://t.co/teBbRzVDv8 https://...  AnderCrenshaw  Crenshaw
# 1  Keeping an eye on TS #Hermine. Latest info ava...  AnderCrenshaw  Crenshaw
# 2  Taking a look back in #RollCall. https://t.co/...  AnderCrenshaw  Crenshaw
# 3  With new school year underway, #LibraryofCongr...  AnderCrenshaw  Crenshaw
# 4  Staff at Naval Station Mayport Athletic and Tr...  AnderCrenshaw  Crenshaw
#
#   first_name birthday gender type state  district       party
# 0      Ander   9/1/44      M  rep    FL       4.0  Republican
# 1      Ander   9/1/44      M  rep    FL       4.0  Republican
# 2      Ander   9/1/44      M  rep    FL       4.0  Republican
# 3      Ander   9/1/44      M  rep    FL       4.0  Republican
# 4      Ander   9/1/44      M  rep    FL       4.0  Republican

# %%
len(df)
# Out:
# 1113951

# %% [markdown]
# ### Sentiment Analysis using TextBlob

# %%
from textblob import TextBlob

# %%
def sentiment_analysis(text):
    return TextBlob(text).sentiment

# %%
print df['text'][90]
sentiment_analysis(df['text'][90])
# Out:
# . @USNavy Larger, more capable fleet key to national security. Read more at https://t.co/FSkXoXvGxo
# Sentiment(polarity=0.24, subjectivity=0.58)

# %%
print df['text'][32]
sentiment_analysis(df['text'][32])
# Out:
# One of Jacksonville's finest, Lt. Col. Sharlene Pigg. Thanks for your service. Best wishes on your retirement!  https://t.co/jpMZNom2UF
# Sentiment(polarity=0.6, subjectivity=0.25)

# %%
print df['text'][282]
sentiment_analysis(df['text'][282])
# Out:
# With @AaronPBean on floor of State Senate as #ABLE Act gets unanimous vote in Tallahassee! http://t.co/CEgB2F631i
# Sentiment(polarity=0.625, subjectivity=0.625)

# %%
print df['text'][728]
sentiment_analysis(df['text'][728])
# Out:
# U.S response to malaria saves lives. Furthering this mission as co-chair of Malaria Caucus.@malarianomore http://t.co/ndrjPligVK
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
print df['text'][823984]
sentiment_analysis(df['text'][823984])
# Out:
# Congrats to #2014WNBAChampions @PhoenixMercury. They were recognized at the WhiteHouse today! #Champions #AZProud http://t.co/yeMAS4qiwx
# Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# ### Sentiment Analysis Using Sentlex
# More Intuitive

# %%
import sentlex
import sentlex.sentanalysis

# %%
def sentlex_analysis(text):
    SWN = sentlex.SWN3Lexicon()
    classifier = sentlex.sentanalysis.BasicDocSentiScore()
    classifier.classify_document(text, tagged=False, L=SWN, a=True, v=True, n=False, r=False, negation=False, verbose=False)
    return classifier.resultdata

# %%
sentlex_analysis(df['text'][0])
# Out:
# {'annotated_doc': '',
#  'doc': u'Never Forget. https://t.co/teBbRzVDv8 https://t.co/xx83hOj8dm',
#  'found_list': Counter({u'//t.co/teBbRzVDv8/JJ': 1}),
#  'resultneg': 0.0,
#  'resultpos': 0.0,
#  'tokens_found': 1,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %%
sentlex_analysis(df['text'][90])
# Out:
# {'annotated_doc': '',
#  'doc': u'. @USNavy Larger, more capable fleet key to national security. Read more at https://t.co/FSkXoXvGxo',
#  'found_list': Counter({u'@/VB': 1,
#           u'Read/VB': 1,
#           u'capable/JJ': 1,
#           u'more/JJR': 1,
#           u'national/JJ': 1}),
#  'resultneg': 0.01875,
#  'resultpos': 0.10511363636363637,
#  'tokens_found': 5,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %%
sentlex_analysis(df['text'][32])
# Out:
# {'annotated_doc': '',
#  'doc': u"One of Jacksonville's finest, Lt. Col. Sharlene Pigg. Thanks for your service. Best wishes on your retirement!  https://t.co/jpMZNom2UF",
#  'found_list': Counter({u'Best/JJS': 1, u'finest/JJS': 1}),
#  'resultneg': 0.0,
#  'resultpos': 0.75,
#  'tokens_found': 2,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %%
sentlex_analysis(df['text'][282])
# Out:
# {'annotated_doc': '',
#  'doc': u'With @AaronPBean on floor of State Senate as #ABLE Act gets unanimous vote in Tallahassee! http://t.co/CEgB2F631i',
#  'found_list': Counter({u'@/JJ': 1, u'gets/VBZ': 1, u'unanimous/JJ': 1}),
#  'resultneg': 0.012152777777777778,
#  'resultpos': 0.0798611111111111,
#  'tokens_found': 3,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %%
sentlex_analysis(df['text'][728])
# Out:
# {'annotated_doc': '',
#  'doc': u'U.S response to malaria saves lives. Furthering this mission as co-chair of Malaria Caucus.@malarianomore http://t.co/ndrjPligVK',
#  'found_list': Counter({u'Furthering/VBG': 1, u'malaria/VB': 1}),
#  'resultneg': 0.0,
#  'resultpos': 0.25,
#  'tokens_found': 2,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %%
sentlex_analysis(df['text'][29385])
# Out:
# {'annotated_doc': '',
#  'doc': u"Enjoyed having you! RT @Yoest: Just wrapped up my senior experience in @CongCulberson 's office! Truly an incredible internship. #TX07",
#  'found_list': Counter({u'@/JJ': 1,
#           u'having/VBG': 1,
#           u'incredible/JJ': 1,
#           u'senior/JJ': 1,
#           u'wrapped/VBD': 1}),
#  'resultneg': 0.02631578947368421,
#  'resultpos': 0.30153508771929827,
#  'tokens_found': 5,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %%
sentlex_analysis(df['text'][432673])
# Out:
# {'annotated_doc': '',
#  'doc': u'Timothy Hovey',
#  'found_list': Counter(),
#  'resultneg': 0.0,
#  'resultpos': 0.0,
#  'tokens_found': 0,
#  'tokens_negated': 0,
#  'unscored_list': []}

# %% [markdown]
# ### LDA Topic Modeling

# %%
# split DataFrames into Republican and Democrat

df_repub = df[df.party == 'Republican']

# %%
# 85         85  703262912782139392  2016-02-26 16:58:39         NaN        1
# 86         86  702974363616862208  2016-02-25 21:52:03         NaN        1
# 87         87  702268223857811458  2016-02-23 23:06:06         NaN        3
# 88         88  699186677630312448  2016-02-15 11:01:08         NaN        2
# 89         89  698690876286091264  2016-02-14 02:11:00         NaN        5
# 90         90  698206042870644736  2016-02-12 18:04:27         NaN        0
# 91         91  697843578580660224  2016-02-11 18:04:09         NaN        2
# 92         92  696798775231320065  2016-02-08 20:52:28         NaN        0
# 93         93  695258648050798592  2016-02-04 14:52:33         NaN        5
# 94         94  694662946350370818  2016-02-02 23:25:27         NaN        0
# 95         95  694662692364251136  2016-02-02 23:24:26         NaN        3
# 96         96  694650575196135425  2016-02-02 22:36:17         NaN        0
# 97         97  694632126893965312  2016-02-02 21:22:59         NaN        7
# 98         98  690579190488375296  2016-01-22 16:58:04         NaN       12
# 99         99  690190309234450436  2016-01-21 15:12:47         NaN        0
#
#    favorite_count              source  \
# 0              12              Buffer
# 1               6     Mobile Web (M5)
# 2               2  Twitter Web Client
# 3               3  Twitter Web Client
# 4               8  Twitter Web Client
# 5               4     Mobile Web (M5)
# 6              13     Mobile Web (M5)
# 7               7  Twitter Web Client
# 8              13  Twitter Web Client
# 9               4  Twitter Web Client
# 10              4  Twitter Web Client
# 11              6  Twitter Web Client
# 12              3  Twitter Web Client
# 13              8  Twitter Web Client
# 14              2  Twitter Web Client
# 15              7  Twitter Web Client
# 16              2  Twitter Web Client
# 17             12              Buffer
# 18              1     Mobile Web (M5)
# 19              5  Twitter Web Client
# 20              3     Mobile Web (M5)
# 21              3  Twitter Web Client
# 22              6  Twitter Web Client
# 23              3  Twitter Web Client
# 24              1  Twitter Web Client
# 25             11  Twitter Web Client
# 26              1  Twitter Web Client
# 27              5  Twitter Web Client
# 28              4     Mobile Web (M5)
# 29              3  Twitter Web Client
# ..            ...                 ...
# 70              9  Twitter Web Client
# 71              0  Twitter Web Client
# 72              0              Buffer
# 73              3  Twitter Web Client
# 74              8  Twitter Web Client
# 75              3  Twitter Web Client
# 76              1  Twitter Web Client
# 77              4  Twitter Web Client
# 78              1  Twitter Web Client
# 79              3     Mobile Web (M5)
# 80              2  Twitter Web Client
# 81              1  Twitter Web Client
# 82              0  Twitter Web Client
# 83              2              Buffer
# 84              0  Twitter Web Client
# 85              1  Twitter Web Client
# 86              0  Twitter Web Client
# 87              1  Twitter Web Client
# 88              2              Buffer
# 89              5     Mobile Web (M5)
# 90              0  Twitter Web Client
# 91              1  Twitter Web Client
# 92              0  Twitter Web Client
# 93              2  Twitter Web Client
# 94              0  Twitter Web Client
# 95              3  Twitter Web Client
# 96              3  Twitter Web Client
# 97             10  Twitter Web Client
# 98              4  Twitter Web Client
# 99              2  Twitter Web Client
#
#                                                  text        twitter  \
# 0   Never Forget. https://t.co/teBbRzVDv8 https://...  AnderCrenshaw
# 1   Keeping an eye on TS #Hermine. Latest info ava...  AnderCrenshaw
# 2   Taking a look back in #RollCall. https://t.co/...  AnderCrenshaw
# 3   With new school year underway, #LibraryofCongr...  AnderCrenshaw
# 87  . @JAXPORT Pressed OMB Director Donovan for an...  AnderCrenshaw
# 88                            https://t.co/DrqybBEVfm  AnderCrenshaw
# 89  On sudden death of Justice Antonin #Scalia, ou...  AnderCrenshaw
# 90  . @USNavy Larger, more capable fleet key to na...  AnderCrenshaw
# 91  .@HouseAppropsGOP @RepHalRogers Tough question...  AnderCrenshaw
# 92  Questions, concerns about #Zika virus? Info at...  AnderCrenshaw
# 93  . @usojax @the_USO lifting spirits of our serv...  AnderCrenshaw
# 94  My vote for Iran Terror Finance Transparency A...  AnderCrenshaw
# 95  Just voted to #overridetheveto of  Restoring A...  AnderCrenshaw
# 96  . @ASBDC Cap Hill event spotlights Jacksonvill...  AnderCrenshaw
# 97  . @NDSS @TheArcUS @AutismSpeaks #ABLEAct conti...  AnderCrenshaw
# 98  .@FairTaxOfficial @FlFairTax  Fairer, simpler ...  AnderCrenshaw
# 99  #IRS Free File has saved taxpayers $1.2 b in f...  AnderCrenshaw
#
#    last_name first_name birthday gender type state  district       party
# 0   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 1   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 2   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 3   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 4   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 5   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 6   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 7   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 8   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 9   Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 10  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 11  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 12  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 13  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 14  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 15  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 16  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 17  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 18  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 19  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 20  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 21  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 22  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 23  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 24  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 25  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 26  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 27  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 28  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 29  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# ..       ...        ...      ...    ...  ...   ...       ...         ...
# 70  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 71  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 72  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 73  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 74  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 75  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 76  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 77  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 78  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 79  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 80  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 81  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 82  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 83  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 84  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 85  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 86  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 87  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 88  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 89  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 90  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 91  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 92  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 93  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 94  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 95  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 96  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 97  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 98  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
# 99  Crenshaw      Ander   9/1/44      M  rep    FL       4.0  Republican
#
# [100 rows x 17 columns]

# %%
len(df_repub)
# Out:
# 558025

# %%
len(df_repub_2016)
# Out:
# 154838

# %%
df_repub['text'].dtypes
# Out:
# dtype('O')

# %%
df_repub['created_at'].dtypes
# Out:
# dtype('O')

# %%
df_repub.iloc[2984]
# Out:
# Unnamed: 0                                                     1824
# id                                                46319799965462528
# created_at                                      2011-03-11 21:21:15
# coordinates                                                     NaN
# retweets                                                          1
# favorite_count                                                    0
# source                                      Twitter for BlackBerry®
# text              @5sahandful I may have to use your line.  Than...
# twitter                                             AustinScottGA08
# last_name                                                     Scott
# first_name                                                   Austin
# birthday                                                   12/10/69
# gender                                                            M
# type                                                            rep
# state                                                            GA
# district                                                          8
# party                                                    Republican
# Name: 2984, dtype: object

# %%
df_dem = df[df.party == 'Democrat']

# %%
df_dem_2016 = df_dem[(df_dem['created_at'] > '2015-12-31') & (df_dem['created_at'] < '2017-01-01')]

# %%
df_dem.head(100)
# Out:
#      Unnamed: 0                  id           created_at coordinates retweets  \
# 3080          0  819659352072134656  2017-01-12 21:36:32         NaN        0
# 3081          1  818930853749334016  2017-01-10 21:21:45         NaN        0
# 3082          2  808347767517179905  2016-12-12 16:28:20         NaN        1
# 3083          3  794619106083356673  2016-11-04 19:15:32         NaN        3
# 3084          4  787025384319684609  2016-10-14 20:20:48         NaN        2
# 3085          5  787023384295137281  2016-10-14 20:12:51         NaN        1
# 3086          6  787021501178449920  2016-10-14 20:05:22         NaN        0
# 3087          7  787011202794811392  2016-10-14 19:24:27         NaN        2
Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# ...        ...        ...      ...    ...  ...   ...       ...       ...
# 3150  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3151  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3152  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3153  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3154  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3155  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3156  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3157  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3158  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3159  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3160  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3161  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3162  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3163  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3164  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3165  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3166  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3167  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3168  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3169  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3170  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3171  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3172  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3173  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3174  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3175  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3176  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3177  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3178  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
# 3179  Thompson     Bennie  1/28/48      M  rep    MS       2.0  Democrat
#
# [100 rows x 17 columns]

# %%
len(df_dem)
# Out:
# 518836

# %%
len(df_dem_2016)
# Out:
# 169401

# %%
# interesting observation: Democrats and Republicans tweeted about the same amount in 2016!

# %%
df_dem.iloc[46657]
# Out:
# Unnamed: 0                                                      608
# id                                               702235046661505025
# created_at                                      2016-02-23 20:54:16
# coordinates                                                     NaN
# retweets                                                         21
# favorite_count                                                   20
# source                                           Twitter Web Client
# text              In many places in this country, men and women ...
# twitter                                              JacksonLeeTX18
# last_name                                               Jackson Lee
# first_name                                                   Sheila
# birthday                                                    1/12/50
# gender                                                            F
# type                                                            rep
# state                                                            TX
# district                                                         18
# party                                                      Democrat
# Name: 91953, dtype: object

# %%
#transform text into array

tmp = [i.lower() for i in df_repub_2016['text']]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(tmp)

# %%
print type(X)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation(n_topics=20, max_iter=5, random_state=1)
lda.fit(X)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_jobs=1, n_topics=20, perp_tol=0.1, random_state=1,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
tf_feature_names = vectorizer.get_feature_names()

# %%
print(type(tf_feature_names))
print(len(tf_feature_names))
print(tf_feature_names[:10])
print(tf_feature_names[-10:])
# Out:
# <type 'list'>
# 196301
# [u'00', u'000', u'00014', u'00092', u'000bosses', u'000mpzqnju', u'000sq', u'000th', u'001', u'0019epk2iy']
# [u'\u0645\u0639\u0647\u0645', u'\u0646\u062f\u0647\u062f', u'\u0646\u06a9\u0646\u06cc\u062f', u'\u0647\u0634\u062f\u0627\u0631', u'\u0647\u0648\u0627\u067e\u06cc\u0645\u0627', u'\u0648\u0627\u0644\u0648\u0644\u0627\u064a\u0627\u062a', u'\u0648\u064a\u0633\u062a\u0639\u0631\u0636', u'\u06a9\u0646\u06af\u0631\u0647', u'\u2070to', u'\u2175cti']

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic {0}:".format(topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic 0:
# https amp need state good new staff hearing
# Topic 1:
# https week time senate today zika life funding
# Topic 2:
# https gt icymi legislation joined ohio future clinton
# Topic 3:
# https congrats year great community floor hatch friend
# Topic 4:
# https health care working forward check looking 11
# Topic 5:
# https utpol israel ct terrorists senorrinhatch abt onthisday
# Topic 6:
# https rt amp today great meeting law students
# Topic 7:
# https today years plan happy news americans birthday
# Topic 8:
# https day today join service thank women family
# Topic 9:
# https thanks morning families discuss honored dc 2016
# Topic 10:
# rt https watch amp potus tonight home congress
# Topic 11:
# https obamacare thank honor report communities states stand
# Topic 12:
# gov texas kids appreciate close nc strengthen mt
# Topic 13:
# https amp read betterway fight like know just
# Topic 14:
# https housegop va job step st grow policies
# Topic 15:
# https help office county great make school stop
# Topic 16:
# https tomorrow sen leadership rights fighting decision dr
# Topic 17:
# https live federal world listen government look ll
# Topic 18:
# https amp obama house president act american veterans
# Topic 19:
# https administration military economy center program needs free
# ()
